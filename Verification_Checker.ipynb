# %%
print(test_images[v])
print("::;;;;")
print(test_images)
print("************")
print(v)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-d224cd567aa0> in <module>()
# ----> 1 print(test_images[v])
#       2 print("::;;;;")
#       3 print(test_images)
#       4 print("************")
#       5 print(v)
#
# NameError: name 'test_images' is not defined

# %% [markdown]
# It is the first one and last code this pair below is relevant and good

# %%
# This is a ID checker AI program using deep learning the actual one the other code below is just "test" code!!!!

# %% [markdown]
# ####

# %% [markdown]
# #

# %%
# #Simple program that tensorflow recommends to beginners
# import tensorflow as tf
# from tensorflow import keras
# from skimage import data
# import os
# import matplotlib.pyplot as plt
# import numpy as np
# import pandas as pd
# def errorHand():
#     print("error")
#     return ""
# DIR_2 = "/Users/jasonmoses/trainingId"
# DIR = "/Users/jasonmoses/dataIDS"
# Category = ["ID","notID"]
# for i in range(2,5):
#     if i<5:
#         for cate in Category:
#             path = os.path.join(DIR,cate)
#             for img in os.listdir(path)[:i]:
#                 if img == os.error.with_traceback:
#                      errorHand()
#                 if i < 5:
#                     print(os.path.join(path,img)[i] + " Test data :####################### " + str(i))
#                 if i < 5 :
#                     print(os.path.splitext(img)[0])
#                 IMG_ARRAY=np.array(data.imread(os.path.join(path,img),as_grey=True))
#                 train_labels=os.path.splitext(img)[0]
#                 train_images=np.resize(IMG_ARRAY,(180,280,90))
#                 print(IMG_ARRAY)
#                 print(train_images[i])
#                 plt.imshow(IMG_ARRAY,cmap=plt.cm.binary)
#                 plt.show()
#                 DATA2=keras.datasets
#                 DATA2=IMG_ARRAY
# for k in range(5):
#      if k<5: 
#         for img in os.listdir(DIR_2):
#             print(img)
#             print(os.listdir(DIR_2)[k])
#             test_images = np.array(data.imread(img,as_grey=True))
#             print(test_images[k])
# model = keras.Sequential([
#     keras.layers.Flatten(input_shape=(280, 90)),
#     keras.layers.Dense(128,activation="relu"),
#     keras.layers.Dense(10,activation="softmax")
# ])
# model.compile(optimizer="adam",loss="sparse_categorical_crossentropy",metrics=["accuracy"])
# model.fit(train_images,os.listdir(path)[1:],epochs=5)
# print(model)

# %%
# This is a id checker program
import tensorflow as tf
tf.enable_eager_execution()
from tensorflow import keras
from skimage import data
import os
import matplotlib.pyplot as plt
import random 
import numpy as np

from pathlib import Path
def errorHand():
    print(" error")
    return " "
DIR_2 = "/Users/jasonmoses/testingId"
DIR = "/Users/jasonmoses/dataIDS"
Category = ["ID","notID"]
train_labels = []
test_labels = []
e=EOFError()
if e!=True: 
    i=25
else:
    print("error with machine model!!!!!" + " This is due to: " + e + errorHand())
for cate in Category:
        path = os.path.join(DIR,cate)
        for img in os.listdir(path)[1:i]:
            if i==i:
                print(img)
                if os.error.with_traceback == True:
                        errorHand()
                print(os.path.join(path,img) + " TrainingtData :####################### Number: " + str(os.listdir(path)[1:i].index(img))+" " 
                      +cate)
                print(os.path.splitext(img)[0])
                IMG_ARRAY=np.array(data.imread(os.path.join(path,img),as_grey=True))[1:]
                for n in os.listdir(path)[1:]:
                    IMG=np.array([data.imread(os.path.join(path,n),as_grey=True)])[1:]
                    train_images=np.resize(IMG,(24,280,90))
                print("........")
                if cate == Category[0]: 
                    print("found Id photo")
                    train_labels.append(Category.index(cate))
                elif cate == Category[1]:
                    print("This photo is not an Id")
                    train_labels.append(Category.index(cate))
                else:
                    print("This is Ds_Store")
                    pass
#                 print(train_labels)
#                 print(IMG_ARRAY)
                plt.imshow(IMG_ARRAY,cmap=plt.cm.binary)
                plt.show()
            else:
                print("")
                errorHand() 
                pass
        k=i
        print("...............................")
        print("Showing TESTING IMAGES NOW")
        print("...............................")
        print(os.listdir(os.path.join(DIR_2,cate)))
        for img_2 in os.listdir(os.path.join(DIR_2,cate)):
            TEST_IMGS = np.array(data.imread(os.path.join(os.path.join(DIR_2,cat),img_2),as_grey=True))[1:]
            if k<=k:
                cat = Path(os.path.join(os.path.join(DIR_2,cate)))
                print(img_2)
                print("^^^^^^^^^^^^^^^^^^^^^^")
                print(str(cat.parent.name))
                if cat == Category[0]:
                    np.array(data.imread(os.path.join(os.path.join(DIR_2,cat),img_2),as_grey=True))[1:]
                elif cat == Category[1]:
                    TEST_IMGS = np.array(data.imread(os.path.join(os.path.join(DIR_2,cat),img_2),as_grey=True))[1:]
                else:
                    print("Was a DS_Store or not in here") 
                print("--------------------------TEST_IMGS------------------------------")
                print(TEST_IMGS)
for v in 5:
    for r in os.listdir(os.path.join(DIR_2,cate))[1:]:
        test_images = np.array([data.imread(os.path.join(os.path.join(DIR_2,cate),r),as_grey=True)])[1:]
        test_images = np.resize(test_images,(24,280,90))
        print(os.path.join(os.path.join(DIR_2,cate),r))
        print("........")
        if cate == Category[0]: 
            print("found Id photo")
            if img_2 != 0:
                test_labels.append(Category.index(cate))
            else:
                test_labels.append(Category.index(cate))
        elif cate == Category[1]:
            print("This photo is not an Id")
            if img_2 != 0:
                test_labels.append(1)
            else:
                test_labels.append(1)
                test_labels.append(1)
        else:
            print("This is Ds_Store")
            pass
plt.imshow(test_images,cmap=plt.cm.binary)
plt.show()
model = keras.Sequential([
      keras.layers.Flatten(input_shape=(280,90)),
      keras.layers.Dense(128,activation="sigmoid"),
      keras.layers.Dense(10,activation="softmax")
])
model.compile(optimizer="adam",loss="sparse_categorical_crossentropy",metrics=["accuracy"])
print("--------------------------------------------------------------------------")
print("//////////////////////////////////")
print("model is processing")
print("******************************************************")
for p in range(10):
    model.fit(train_images[p],train_labels[p],epochs=80)
    test_loss,test_acc=model.evaluate(test_images[p], test_labels[p])
#DONT UNCOMMNENT THE LINE BELOW UNTIL THE MODEL IS READY TO BE SAVED THEN UNCOMMENT AND AFTER THAT RUN -> this will save the model to a path
# model.save('Verification_ML_Model')        
print(os.listdir(DIR_2)[1:])
print("!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!")
print("Now showing results for images")            
for v in range(5): 
        print(test_acc)
        prediction=model.predict(test_images)
        print(round(np.amax(prediction)))
        print(prediction)
        print(";;;")
        print(test_images[v])
        plt.grid(False)
        plt.imshow(test_images[v],cmap=plt.cm.binary)
        plt.xlabel("Actual: " + cate)
        plt.title("Prediction: " + Category[int(round(np.amax(prediction)))])
        plt.show()
# Out:
# download.jpg
# /Users/jasonmoses/dataIDS/ID/download.jpg TrainingtData :####################### Number: 0 ID
# download
# ........
# found Id photo
# id-kaart-2019.jpg
# /Users/jasonmoses/dataIDS/ID/id-kaart-2019.jpg TrainingtData :####################### Number: 1 ID
# id-kaart-2019
# ........
# found Id photo
# idsa.png
# /Users/jasonmoses/dataIDS/ID/idsa.png TrainingtData :####################### Number: 2 ID
# idsa
# ........
# found Id photo
# images-7.jpg
# /Users/jasonmoses/dataIDS/ID/images-7.jpg TrainingtData :####################### Number: 3 ID
# images-7
# ........
# found Id photo
# images-6.jpg
# /Users/jasonmoses/dataIDS/ID/images-6.jpg TrainingtData :####################### Number: 4 ID
# images-6
# ........
# found Id photo
# images-4.jpg
# /Users/jasonmoses/dataIDS/ID/images-4.jpg TrainingtData :####################### Number: 5 ID
# images-4
# ........
# found Id photo
# images-5.jpg
# /Users/jasonmoses/dataIDS/ID/images-5.jpg TrainingtData :####################### Number: 6 ID
# images-5
# ........
# found Id photo
# images-1.jpg
# /Users/jasonmoses/dataIDS/ID/images-1.jpg TrainingtData :####################### Number: 7 ID
# images-1
# ........
# found Id photo
# images-2.jpg
# /Users/jasonmoses/dataIDS/ID/images-2.jpg TrainingtData :####################### Number: 8 ID
# images-2
# ........
# found Id photo
# images-3.jpg
# /Users/jasonmoses/dataIDS/ID/images-3.jpg TrainingtData :####################### Number: 9 ID
# images-3
# ........
# found Id photo
# images-13.jpg
# /Users/jasonmoses/dataIDS/ID/images-13.jpg TrainingtData :####################### Number: 10 ID
# images-13
# ........
# found Id photo
# images-12.jpg
# /Users/jasonmoses/dataIDS/ID/images-12.jpg TrainingtData :####################### Number: 11 ID
# images-12
# ........
# found Id photo
# id.jpg
# /Users/jasonmoses/dataIDS/ID/id.jpg TrainingtData :####################### Number: 12 ID
# id
# ........
# found Id photo
# id.jpeg
# /Users/jasonmoses/dataIDS/ID/id.jpeg TrainingtData :####################### Number: 13 ID
# id
# ........
# found Id photo
# images-10.jpg
# /Users/jasonmoses/dataIDS/ID/images-10.jpg TrainingtData :####################### Number: 14 ID
# images-10
# ........
# found Id photo
# images-11.jpg
# /Users/jasonmoses/dataIDS/ID/images-11.jpg TrainingtData :####################### Number: 15 ID
# images-11
# ........
# found Id photo
# images-8.jpg
# /Users/jasonmoses/dataIDS/ID/images-8.jpg TrainingtData :####################### Number: 16 ID
# images-8
# ........
# found Id photo
# unnamed.jpg
# /Users/jasonmoses/dataIDS/ID/unnamed.jpg TrainingtData :####################### Number: 17 ID
# unnamed
# ........
# found Id photo
# images-14.jpg
# /Users/jasonmoses/dataIDS/ID/images-14.jpg TrainingtData :####################### Number: 18 ID
# images-14
# ........
# found Id photo
# Gupta-visa.jpg
# /Users/jasonmoses/dataIDS/ID/Gupta-visa.jpg TrainingtData :####################### Number: 19 ID
# Gupta-visa
# ........
# found Id photo
# images-9.jpg
# /Users/jasonmoses/dataIDS/ID/images-9.jpg TrainingtData :####################### Number: 20 ID
# images-9
# ........
# found Id photo
# images-16.jpg
# /Users/jasonmoses/dataIDS/ID/images-16.jpg TrainingtData :####################### Number: 21 ID
# images-16
# ........
# found Id photo
# download-2.jpg
# /Users/jasonmoses/dataIDS/ID/download-2.jpg TrainingtData :####################### Number: 22 ID
# download-2
# ........
# found Id photo
# Logo_anneline id 1.jpg
# /Users/jasonmoses/dataIDS/ID/Logo_anneline id 1.jpg TrainingtData :####################### Number: 23 ID
# Logo_anneline id 1
# ........
# found Id photo
# ...............................
# Showing TESTING IMAGES NOW
# ...............................
# ['.DS_Store', 'MobileID.png', 'images-15.jpg', 'download-3.jpg', 'id3.jpg', 'download-2.jpg', 'download-5.jpg']
# ---------------------------------------------------------------------------
# NotADirectoryError                        Traceback (most recent call last)
# <ipython-input-16-277c7e5aba23> in <module>()
#      61         print(os.listdir(os.path.join(DIR_2,cate)))
#      62         for img_2 in os.listdir(os.path.join(DIR_2,cate)):
# ---> 63             TEST_IMGS = np.array(data.imread(os.path.join(os.path.join(DIR_2,cat),img_2),as_grey=True))[1:]
#      64             if k<=k:
#      65                 cat = Path(os.path.join(os.path.join(DIR_2,cate)))
#
# ~/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py in imread(fname, as_grey, plugin, flatten, **plugin_args)
#      59
#      60     with file_or_url_context(fname) as fname:
# ---> 61         img = call_plugin('imread', fname, plugin=plugin, **plugin_args)
#      62
#      63     if not hasattr(img, 'ndim'):
#
# ~/anaconda3/lib/python3.6/site-packages/skimage/io/manage_plugins.py in call_plugin(kind, *args, **kwargs)
#     209                                (plugin, kind))
#     210
# --> 211     return func(*args, **kwargs)
#     212
#     213
#
# ~/anaconda3/lib/python3.6/site-packages/skimage/io/_plugins/pil_plugin.py in imread(fname, dtype, img_num, **kwargs)
#      33     """
#      34     if isinstance(fname, string_types):
# ---> 35         with open(fname, 'rb') as f:
#      36             im = Image.open(f)
#      37             return pil_to_ndarray(im, dtype=dtype, img_num=img_num)
#
# NotADirectoryError: [Errno 20] Not a directory: '/Users/jasonmoses/testingId/notID/download-6.jpg/.DS_Store'

# %%
100 * 100
# Out:
# 10000

# %%
import os
import matplotlib.pyplot as plt
import random 
from pathlib import Path
from skimage import data
from tensorflow import keras
import numpy as np
def errorHand():
    print(" error")
    return " "
DIR_2 = "/Users/jasonmoses/testingId"
DIR = "/Users/jasonmoses/dataIDS"
Category = ["ID", "notID"]
train_labels = []
test_labels = []
e = EOFError()
def call():
    print("button pressed")
if e != True:
    i = 25
else:
    print("error with machine model!!!!!" + " This is due to: " + e + errorHand())
for cate in Category:
    path = os.path.join(DIR, cate)
    for img in os.listdir(path)[1:i]:
        if i == i:
            print(img)
            if os.error.with_traceback == True:
                errorHand()
            print(os.path.join(path, img) + " TrainingtData :####################### Number: " + str(os.listdir(path)[1:i].index(img)) + " " + cate)
            print(os.path.splitext(img)[0])
            IMG_ARRAY = np.array(data.imread(os.path.join(path, img), as_grey=True))[1:]
            for n in os.listdir(path)[1:]:
                IMG = np.array([data.imread(os.path.join(path, n), as_grey=True)])[1:]
                train_images = np.resize(IMG, (48, 280, 90))
            print("........")
            if cate == Category[0]:
                print("found Id photo")
                train_labels.append(Category.index(cate))
            elif cate == Category[1]:
                print("This photo is not an Id")
                train_labels.append(Category.index(cate))
            else:
                print("This is Ds_Store")
                pass
#             print(train_labels)       
#             print(IMG_ARRAY)
#             plt.imshow(IMG_ARRAY, cmap=plt.cm.binary)
#             plt.colorbar()
#             plt.show()
        else:
            print("")
            errorHand()
            pass
    k = i
    print("...............................")
    print("Showing TESTING IMAGES NOW")
    print("...............................")
    print(os.listdir(os.path.join(DIR_2, cate)))
    for img_2 in os.listdir(os.path.join(DIR_2, cate))[1:]:
        if k <= k:
            print(img_2)
            for l in os.listdir(os.path.join(DIR_2,cate)):
                    cat = Path(os.path.join(os.path.join(DIR_2, cate), l))
            print(img_2)
            print("^^^^^^^^^^^^^^^^^^^^^^")
            print("type is " + str(cat.parent.name))
            print("--------------------------TEST_IMGS------------------------------")
            TEST_IMG = np.array(data.imread(os.path.join(os.path.join(DIR_2, cate), img_2), as_grey=True))[1:]
            for r in os.listdir(os.path.join(DIR_2, cate))[1:]:
                IMG_2 = np.array([data.imread(os.path.join(os.path.join(DIR_2, cate), r), as_grey=True)])
                test_images = np.resize(IMG_2, (10, 280, 90))
            print(os.path.join(os.path.join(DIR_2, cate), r))
            print("........")
            print("@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@")
            if  cate == Category[0]:
                test_labels.append(Category.index(str(cat.parent.name)))
                print("**************************************")
                print("found Id photo of Test")
                print("**************************************")
            elif cate == Category[1]:
                test_labels.append(Category.index(str(cat.parent.name)))
                print("**************************************")
                print("This photo is not an Id Test")
                print("**************************************")
            else:
                print("This is Ds_Store Test")
                pass
# print("----------------------------------------------Test Images------------------------------")
# print(test_images)
# print("----------------------------------------------Test Labels------------------------------")
# print(test_labels)
# print("----------------------------------------------Train Images------------------------------")
# print(train_images)
# print("----------------------------------------------Train Labels------------------------------")
# print(train_labels)
model = keras.Sequential([
keras.layers.Flatten(input_shape=(280, 90)),
keras.layers.Dense(280, activation="softmax"),
keras.layers.Dense(70, activation="sigmoid")
])
model.compile(optimizer="adam", loss="sparse_categorical_crossentropy", metrics=["accuracy"])
print("--------------------------------------------------------------------------")
print("//////////////////////////////////")
print("model is processing")
print("******************************************************")
model.fit(train_images, train_labels, epochs=5)
test_loss, test_acc = model.evaluate(test_images, test_labels)
#DONT UNCOMMNENT THE LINE BELOW UNTIL THE MODEL IS READY TO BE SAVED THEN UNCOMMENT AND AFTER THAT RUN ->
# model.save('Verification_ML_Model')
print(os.listdir(DIR_2)[1:])
print("!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!")
print("Now showing results for images")
prediction = model.predict(test_images)
for v in range(5):
    print("-------Test_Acc------------")
    print(test_acc)
    print("Accuracy: " + str(test_acc))
    print(np.max(prediction))
    print("prediction: "+ str((prediction)))
    print(";;;")
    plt.xlabel("Actual: " + cate)
    plt.title("Prediction: " + Category[int(round(np.max((prediction))))])
    plt.ylabel("Number of index:" + str(v))
    plt.imshow(TEST_IMG[v])
    plt.show()
# Out:
# /Users/jasonmoses/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# download.jpg
# /Users/jasonmoses/dataIDS/ID/download.jpg TrainingtData :####################### Number: 0 ID
# download
# ........
# found Id photo
# id-kaart-2019.jpg
# /Users/jasonmoses/dataIDS/ID/id-kaart-2019.jpg TrainingtData :####################### Number: 1 ID
# id-kaart-2019
# ........
# found Id photo
# idsa.png
# /Users/jasonmoses/dataIDS/ID/idsa.png TrainingtData :####################### Number: 2 ID
# idsa
# ........
# found Id photo
# images-7.jpg
# /Users/jasonmoses/dataIDS/ID/images-7.jpg TrainingtData :####################### Number: 3 ID
# images-7
# ........
# found Id photo
# images-6.jpg
# /Users/jasonmoses/dataIDS/ID/images-6.jpg TrainingtData :####################### Number: 4 ID
# images-6
# ........
# found Id photo
# images-4.jpg
# /Users/jasonmoses/dataIDS/ID/images-4.jpg TrainingtData :####################### Number: 5 ID
# images-4
# ........
# found Id photo
# images-5.jpg
# /Users/jasonmoses/dataIDS/ID/images-5.jpg TrainingtData :####################### Number: 6 ID
# images-5
# ........
# found Id photo
# images-1.jpg
# /Users/jasonmoses/dataIDS/ID/images-1.jpg TrainingtData :####################### Number: 7 ID
# images-1
# ........
# found Id photo
# images-2.jpg
# /Users/jasonmoses/dataIDS/ID/images-2.jpg TrainingtData :####################### Number: 8 ID
# images-2
# ........
# found Id photo
# images-3.jpg
# /Users/jasonmoses/dataIDS/ID/images-3.jpg TrainingtData :####################### Number: 9 ID
# images-3
# ........
# found Id photo
# images-13.jpg
# /Users/jasonmoses/dataIDS/ID/images-13.jpg TrainingtData :####################### Number: 10 ID
# images-13
# ........
# found Id photo
# images-12.jpg
# /Users/jasonmoses/dataIDS/ID/images-12.jpg TrainingtData :####################### Number: 11 ID
# images-12
# ........
# found Id photo
# id.jpg
# /Users/jasonmoses/dataIDS/ID/id.jpg TrainingtData :####################### Number: 12 ID
# id
# ........
# found Id photo
# id.jpeg
# /Users/jasonmoses/dataIDS/ID/id.jpeg TrainingtData :####################### Number: 13 ID
# id
# ........
# found Id photo
# images-10.jpg
# /Users/jasonmoses/dataIDS/ID/images-10.jpg TrainingtData :####################### Number: 14 ID
# images-10
# ........
# found Id photo
# images-11.jpg
# /Users/jasonmoses/dataIDS/ID/images-11.jpg TrainingtData :####################### Number: 15 ID
# images-11
# ........
# found Id photo
# images-8.jpg
# /Users/jasonmoses/dataIDS/ID/images-8.jpg TrainingtData :####################### Number: 16 ID
# images-8
# ........
# found Id photo
# unnamed.jpg
# /Users/jasonmoses/dataIDS/ID/unnamed.jpg TrainingtData :####################### Number: 17 ID
# unnamed
# ........
# found Id photo
# images-14.jpg
# /Users/jasonmoses/dataIDS/ID/images-14.jpg TrainingtData :####################### Number: 18 ID
# images-14
# ........
# found Id photo
# Gupta-visa.jpg
# /Users/jasonmoses/dataIDS/ID/Gupta-visa.jpg TrainingtData :####################### Number: 19 ID
# Gupta-visa
# ........
# found Id photo
# images-9.jpg
# /Users/jasonmoses/dataIDS/ID/images-9.jpg TrainingtData :####################### Number: 20 ID
# images-9
# ........
# found Id photo
# images-16.jpg
# /Users/jasonmoses/dataIDS/ID/images-16.jpg TrainingtData :####################### Number: 21 ID
# images-16
# ........
# found Id photo
# download-2.jpg
# /Users/jasonmoses/dataIDS/ID/download-2.jpg TrainingtData :####################### Number: 22 ID
# download-2
# ........
# found Id photo
# Logo_anneline id 1.jpg
# /Users/jasonmoses/dataIDS/ID/Logo_anneline id 1.jpg TrainingtData :####################### Number: 23 ID
# Logo_anneline id 1
# ........
# found Id photo
# ...............................
# Showing TESTING IMAGES NOW
# ...............................
# ['.DS_Store', 'MobileID.png', 'images-15.jpg', 'download-3.jpg', 'id3.jpg', 'download-2.jpg', 'download-5.jpg']
# MobileID.png
# MobileID.png
# ^^^^^^^^^^^^^^^^^^^^^^
# type is ID
# --------------------------TEST_IMGS------------------------------
# /Users/jasonmoses/testingId/ID/download-5.jpg
# ........
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# **************************************
# found Id photo of Test
# **************************************
# images-15.jpg
# images-15.jpg
# ^^^^^^^^^^^^^^^^^^^^^^
# type is ID
# --------------------------TEST_IMGS------------------------------
# /Users/jasonmoses/testingId/ID/download-5.jpg
# ........
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# **************************************
# found Id photo of Test
# **************************************
# download-3.jpg
# download-3.jpg
# ^^^^^^^^^^^^^^^^^^^^^^
# type is ID
# --------------------------TEST_IMGS------------------------------
# /Users/jasonmoses/testingId/ID/download-5.jpg
# ........
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# **************************************
# found Id photo of Test
# **************************************
# id3.jpg
# id3.jpg
# ^^^^^^^^^^^^^^^^^^^^^^
# type is ID
# --------------------------TEST_IMGS------------------------------
# /Users/jasonmoses/testingId/ID/download-5.jpg
# ........
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# **************************************
# found Id photo of Test
# **************************************
# download-2.jpg
# download-2.jpg
# ^^^^^^^^^^^^^^^^^^^^^^
# type is ID
# --------------------------TEST_IMGS------------------------------
# /Users/jasonmoses/testingId/ID/download-5.jpg
# ........
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# **************************************
# found Id photo of Test
# **************************************
# download-5.jpg
# download-5.jpg
# ^^^^^^^^^^^^^^^^^^^^^^
# type is ID
# --------------------------TEST_IMGS------------------------------
# /Users/jasonmoses/testingId/ID/download-5.jpg
# ........
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# **************************************
# found Id photo of Test
# **************************************
# download.jpg
# /Users/jasonmoses/dataIDS/notID/download.jpg TrainingtData :####################### Number: 0 notID
# download
# ........
# This photo is not an Id
# images-7.jpg
# /Users/jasonmoses/dataIDS/notID/images-7.jpg TrainingtData :####################### Number: 1 notID
# images-7
# ........
# This photo is not an Id
# images-4.jpg
# /Users/jasonmoses/dataIDS/notID/images-4.jpg TrainingtData :####################### Number: 2 notID
# images-4
# ........
# This photo is not an Id
# images-19.jpg
# /Users/jasonmoses/dataIDS/notID/images-19.jpg TrainingtData :####################### Number: 3 notID
# images-19
# ........
# This photo is not an Id
# images-24.jpg
# /Users/jasonmoses/dataIDS/notID/images-24.jpg TrainingtData :####################### Number: 4 notID
# images-24
# ........
# This photo is not an Id
# images-18.jpg
# /Users/jasonmoses/dataIDS/notID/images-18.jpg TrainingtData :####################### Number: 5 notID
# images-18
# ........
# This photo is not an Id
# images-5.jpg
# /Users/jasonmoses/dataIDS/notID/images-5.jpg TrainingtData :####################### Number: 6 notID
# images-5
# ........
# This photo is not an Id
# images-1.jpg
# /Users/jasonmoses/dataIDS/notID/images-1.jpg TrainingtData :####################### Number: 7 notID
# images-1
# ........
# This photo is not an Id
# images-20.jpg
# /Users/jasonmoses/dataIDS/notID/images-20.jpg TrainingtData :####################### Number: 8 notID
# images-20
# ........
# This photo is not an Id
# images-2.jpg
# /Users/jasonmoses/dataIDS/notID/images-2.jpg TrainingtData :####################### Number: 9 notID
# images-2
# ........
# This photo is not an Id
# images-23.jpg
# /Users/jasonmoses/dataIDS/notID/images-23.jpg TrainingtData :####################### Number: 10 notID
# images-23
# ........
# This photo is not an Id
# images-22.jpg
# /Users/jasonmoses/dataIDS/notID/images-22.jpg TrainingtData :####################### Number: 11 notID
# images-22
# ........
# This photo is not an Id
# images-3.jpg
# /Users/jasonmoses/dataIDS/notID/images-3.jpg TrainingtData :####################### Number: 12 notID
# images-3
# ........
# This photo is not an Id
# images-13.jpg
# /Users/jasonmoses/dataIDS/notID/images-13.jpg TrainingtData :####################### Number: 13 notID
# images-13
# ........
# This photo is not an Id
# images-12.jpg
# /Users/jasonmoses/dataIDS/notID/images-12.jpg TrainingtData :####################### Number: 14 notID
# images-12
# ........
# This photo is not an Id
# images-10.jpg
# /Users/jasonmoses/dataIDS/notID/images-10.jpg TrainingtData :####################### Number: 15 notID
# images-10
# ........
# This photo is not an Id
# images-11.jpg
# /Users/jasonmoses/dataIDS/notID/images-11.jpg TrainingtData :####################### Number: 16 notID
# images-11
# ........
# This photo is not an Id
# images-8.jpg
# /Users/jasonmoses/dataIDS/notID/images-8.jpg TrainingtData :####################### Number: 17 notID
# images-8
# ........
# This photo is not an Id
# images-15.jpg
# /Users/jasonmoses/dataIDS/notID/images-15.jpg TrainingtData :####################### Number: 18 notID
# images-15
# ........
# This photo is not an Id
# images-14.jpg
# /Users/jasonmoses/dataIDS/notID/images-14.jpg TrainingtData :####################### Number: 19 notID
# images-14
# ........
# This photo is not an Id
# images-9.jpg
# /Users/jasonmoses/dataIDS/notID/images-9.jpg TrainingtData :####################### Number: 20 notID
# images-9
# ........
# This photo is not an Id
# images-16.jpg
# /Users/jasonmoses/dataIDS/notID/images-16.jpg TrainingtData :####################### Number: 21 notID
# images-16
# ........
# This photo is not an Id
# images-17.jpg
# /Users/jasonmoses/dataIDS/notID/images-17.jpg TrainingtData :####################### Number: 22 notID
# images-17
# ........
# This photo is not an Id
# download-3.jpg
# /Users/jasonmoses/dataIDS/notID/download-3.jpg TrainingtData :####################### Number: 23 notID
# download-3
# ........
# This photo is not an Id
# ...............................
# Showing TESTING IMAGES NOW
# ...............................
# ['download.jpg', 'images-21.jpg', 'download-1.jpg', 'download-4.jpg', 'download-6.jpg']
# images-21.jpg
# images-21.jpg
# ^^^^^^^^^^^^^^^^^^^^^^
# type is notID
# --------------------------TEST_IMGS------------------------------
# /Users/jasonmoses/testingId/notID/download-6.jpg
# ........
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# **************************************
# This photo is not an Id Test
# **************************************
# download-1.jpg
# download-1.jpg
# ^^^^^^^^^^^^^^^^^^^^^^
# type is notID
# --------------------------TEST_IMGS------------------------------
# /Users/jasonmoses/testingId/notID/download-6.jpg
# ........
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# **************************************
# This photo is not an Id Test
# **************************************
# download-4.jpg
# download-4.jpg
# ^^^^^^^^^^^^^^^^^^^^^^
# type is notID
# --------------------------TEST_IMGS------------------------------
# /Users/jasonmoses/testingId/notID/download-6.jpg
# ........
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# **************************************
# This photo is not an Id Test
# **************************************
# download-6.jpg
# download-6.jpg
# ^^^^^^^^^^^^^^^^^^^^^^
# type is notID
# --------------------------TEST_IMGS------------------------------
# /Users/jasonmoses/testingId/notID/download-6.jpg
# ........
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# **************************************
# This photo is not an Id Test
# **************************************
# WARNING:tensorflow:From /Users/jasonmoses/anaconda3/lib/python3.6/site-packages/tensorflow/python/ops/resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# --------------------------------------------------------------------------
# //////////////////////////////////
# model is processing
# ******************************************************
# Epoch 1/5

# %%
# Out:
# 2494

# %%
# Out:
# 7901325

# %%
# Out:
# 2610883

# %%
# Out:
# 231803
